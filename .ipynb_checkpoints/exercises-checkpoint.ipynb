# %%
import pandas as pd
df = pd.read_csv('500_Person_Gender_Height_Weight_Index.csv')
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
data = df.iloc[:,-3:].values
data
# Out:
# array([[174,  96,   4],
#        [189,  87,   2],
#        [185, 110,   4],
#        ...,
#        [141, 136,   5],
#        [150,  95,   5],
#        [173, 131,   5]])

# %%
#1- Find the number of dimensions, the size and the shape of this array
print(data.ndim)
print(data.size)
print(data.shape)
# Out:
# 2
# 1500
# (500, 3)

# %%
#2- What is the data type of this array?
data.dtype
# Out:
# dtype('int64')

# %%
#3- Return the target value of the 500 observation
data[500 - 1]
# Out:
# array([173, 131,   5])

# %%
#4- Extract every 3 observations of the data
data[::3,:]
# Out:
# array([[174,  96,   4],
#        [195, 104,   3],
#        [147,  92,   5],
#        [169, 103,   4],
#        [192, 101,   3],
#        [153, 107,   5],
#        [144, 145,   5],
#        [153, 149,   5],
#        [172,  67,   2],
#        [187,  62,   1],
#        [153, 121,   5],
#        [160, 131,   5],
#        [197, 114,   3],
#        [185,  81,   2],
#        [157,  56,   2],
#        [185,  76,   2],
#        [161,  72,   3],
#        [176,  54,   1],
#        [196, 116,   4],
#        [178, 127,   5],
#        [191,  54,   0],
#        [190,  83,   2],
#        [172,  96,   4],
#        [194, 136,   4],
#        [141,  80,   5],
#        [197, 154,   4],
#        [176, 122,   4],
#        [166, 140,   5],
#        [168, 123,   5],
#        [145, 117,   5],
#        [178, 154,   5],
#        [177,  61,   2],
#        [142,  69,   4],
#        [190,  50,   0],
#        [161, 155,   5],
#        [195, 126,   4],
#        [181, 106,   4],
#        [146, 157,   5],
# ...

# %%
#5- Extract the first and last features in one array. (using hstack)
import numpy as np
np.hstack([data[0],data[len(data) - 1]])
# Out:
# array([174,  96,   4, 173, 131,   5])

# %%
#6- Reverse the array (the Last observation becomes the first)
data[::-1]
# Out:
# array([[173, 131,   5],
#        [150,  95,   5],
#        [141, 136,   5],
#        ...,
#        [185, 110,   4],
#        [189,  87,   2],
#        [174,  96,   4]])

# %%
#7- What is the maximum and minimum height?
print(data[:,0].min())
print(data[:,0].max())
# Out:
# 140
# 199

# %%
#8- What is the maximum and minimum weight?
print(data[:,1].min())
print(data[:,1].max())
# Out:
# 50
# 160

# %%
#9- Find the mean and standard deviation of height using the simple operations only.
mean = data[:,0].sum() / len(data)# mean = sum / count
mean
standard_deviation= data[:,0].std()
standard_deviation
# Out:
# 16.35887722308594

# %%
#10- Find the mean and standard deviation of weight using the simple operations only.
mean = data[:,1].sum() / len(data)# mean = sum / count
print(mean)
standard_deviation= data[:,1].std()
print(standard_deviation)
# Out:
# 106.0
# 32.350208654659404

# %%
#11- Find the mean and standard deviation of height.

# %%
#12- Find the mean and standard deviation of weight.

# %%
#13- Find the 25th, 75th percentile and the median for height
np.percentile(data[:,0],25)
np.percentile(data[:,0],75)
# Out:
# 184.0

# %%
#14- Find the 25th, 75th percentile and the median for width
np.percentile(data[:,1],25)
np.percentile(data[:,1],75)
np.median(data[:,1])
# Out:
# 106.0

# %%
#15- Normalize height and width

# %%
#16- What are the indices of the tallest people?
data[:,0].argmax()
# Out:
# 100

# %%
#17- Create two arrays representing the square of both height and weight
out = np.empty(len(data))
x = np.square(data[:,0],out = out)
print(out)
y = np.square(data[:,1],out = out)
print(out)
# Out:
# [30276. 35721. 34225. 38025. 22201. 35721. 21609. 23716. 30276. 28561.
#  38025. 25281. 36864. 24025. 36481. 23409. 24649. 19600. 20736. 29584.
#  24649. 23409. 28561. 34225. 29584. 22801. 36100. 34969. 26569. 32041.
#  23409. 31684. 38025. 25600. 24649. 35721. 38809. 20736. 29241. 34225.
#  30625. 22201. 24649. 25921. 33124. 34225. 35344. 32761. 25921. 19600.
#  28224. 30976. 26569. 29584. 38416. 34969. 29584. 31684. 26896. 20449.
#  36481. 19881. 37249. 36100. 30625. 32041. 29584. 28224. 26896. 37636.
#  23409. 31684. 19881. 32400. 34225. 38809. 27225. 28224. 30976. 32761.
#  26896. 27556. 36100. 34596. 28224. 39204. 30625. 21025. 25281. 34225.
#  31684. 33489. 37636. 31329. 38809. 28900. 20164. 25600. 38025. 36100.
#  39601. 23716. 25921. 39204. 36864. 38025. 27556. 25281. 32761. 22201.
#  22500. 21316. 36100. 36864. 31329. 21904. 27225. 21316. 20736. 30976.
#  28224. 34969. 34969. 33856. 24964. 24964. 37636. 21025. 33124. 23716.
# ...

# %%
#18- Create two arrays representing the square root of both height and weight
out = np.empty(len(data))
x = np.sqrt(data[:,0],out = out)
y = np.sqrt(data[:,1],out = out)
print(out)
# Out:
# [ 9.79795897  9.32737905 10.48808848 10.19803903  7.81024968 10.19803903
#   9.59166305 10.53565375  9.48683298 10.14889157  9.          8.94427191
#  10.04987562  7.14142843  8.88819442 10.34408043 10.48808848 11.35781669
#  12.04159458 11.78982612 10.48808848 12.20655562  9.8488578  11.78982612
#   8.18535277  8.          9.74679434  7.87400787 12.60952021 12.32882801
#  11.          7.21110255  8.06225775 11.44552314 12.36931688 11.48912529
#  10.67707825  8.94427191 12.32882801  9.         10.95445115 10.39230485
#   7.48331477 10.86278049 11.22497216  8.71779789 11.04536102 10.53565375
#   8.48528137 12.32882801 11.61895004  7.34846923 10.48808848 10.24695077
#  10.77032961  9.43398113  9.59166305 11.26942767  8.36660027  9.38083152
#   7.34846923 11.95826074  7.34846923  9.11043358 11.61895004 12.56980509
#   9.79795897  7.68114575  9.05538514 11.66190379  7.14142843 10.81665383
#   8.94427191  8.66025404 10.         12.40967365 10.19803903  9.48683298
# ...

# %%
#19- Extract the last column of the data (the target). What will be its shape?
data[:,-1:].shape
# Out:
# (500, 1)

# %%
#20- make it a column vector
data[:,np.newaxis].shape
# Out:
# (500, 1, 3)
